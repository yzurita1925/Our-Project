# %%
import pandas as pd

# %%
# The transportation data has been filtered down to work conditions data
base_df = pd.read_csv("County_Transportation_Profiles_V2.csv")
base_df.head()
# Out:
#    County FIPS     County Name  State FIPS State Name  \
# 0         1001  Autauga County           1    Alabama
# 1         1003  Baldwin County           1    Alabama
# 2         1005  Barbour County           1    Alabama
# 3         1007     Bibb County           1    Alabama
# 4         1009   Blount County           1    Alabama
#
#    Number of business establishments  \
# 0                              869.0
# 1                             5384.0
# 2                              455.0
# 3                              284.0
# 4                              698.0
#
#    Number of resident workers who work at home  \
# 0                                        510.0
# 1                                       4380.0
# 2                                        110.0
# 3                                        100.0
# 4                                        480.0
#
#    Number of workers from other counties who commute to work in the county  \
# ...
